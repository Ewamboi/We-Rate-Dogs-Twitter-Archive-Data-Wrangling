# %% [markdown]
# # DATA WARNGLING REPORT

# %% [markdown]
# ## DATA GATHERING

# %% [markdown]
# I started by gathering the data that i will require in this excersise. This is by downloading manually the twitter_archive_enhanced.csv data then i uploaded it in my notebook. additionally i downloaded the image_predictions.tsv file then uploaded it also. i didnt get to use my own json file so i downloaded the one provided in the classroom then uploaded it.
# The next step that i took was to load all the libraries that i required pandas, numpy, seaborn, os, matplotlib, request,then i read all my files programmatically.

# %% [markdown]
# ## CLEANING

# %% [markdown]
# The data being used was fro different data sources so it definetly has some issues. The task was to identify 8 different quality issues and i managed to identify them by first by use of virtual assesment. By just looking at the data you could see that there were some missing values in different columns. I had to validate what i saw by use of programmatic assessment and functions such as info() came in handy. The umage of the dog below was assessed programatticaly by using the function Image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## QUALITY ISSUES AND TIDENESS

# %% [markdown]
#     Archive table
# Remove the retweets and  keep the original tweets. This was done by use of the isnull function that removed all the null values in the retweeted_status_user_id.
#
# Remove columns that we dont need for this analysis. At this stage the drop function was used to remove all the columns that we did not require for this analysis.
#
# code tweet_id with the  right data type code. Initilly the tweet_id was coded as an integer so i had to change it to a string
#
# code timestamp with the right data type code. Timestap was coded as a string and we had to change it to date and time for a smooth analysis
#
# Missing names that are represented as none. This was done by changing missing names as NaN
#
# Remove the hyperlinks from the text which was done by defining the htmlink function.
#
# Source column is in form of HTML but not a normal string format by use of the exctract function
#
#
#     Image table
#
# Diffreent dogs in columns p1, p2, and p3 had some uppercase and lowercase letters. This was done by changing all the cases to lower case

# %% [markdown]
# ## Tidiness issues

# %% [markdown]
# create one column for the different dog stages do away with the previous ones
#
# All the three tables should be merged. After merging the first two table i added the last one whicch was the image_pred_clean data.
# Drop the tweets that doesnt have images by use of the drop function
#
# The next step that i took was doing some cleaning by dropping tweets that didnt have images then i chaged my data types again which was later saved as the twitter_archive_master.csv
